# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #  Load Data

# %%
data =pd.read_csv('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.csv')

# %% [markdown]
# # Basic check on the Dataset

# %%
# head
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
#sample
data.sample(10)
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 1098   E100816   25    Male             Medical       Married
# 481   E1001866   39    Male             Medical       Married
# 935    E100560   38    Male             Medical       Married
# 1091   E100805   25  Female       Life Sciences        Single
# 746   E1002316   32    Male    Technical Degree        Single
# 4     E1001010   60    Male           Marketing        Single
# 1063   E100761   40  Female       Life Sciences       Married
# 855    E100425   34    Male       Life Sciences        Single
# 459   E1001828   40    Male             Medical        Single
# 297   E1001533   43    Male       Life Sciences       Married
#
#                EmpDepartment          EmpJobRole BusinessTravelFrequency  \
# 1098             Development           Developer           Travel_Rarely
# 481                    Sales     Sales Executive           Travel_Rarely
# ...

# %%
#columns in data set
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
#shape of the data set
data.shape
# Out:
# (1200, 28)

# %%
#Data type present in the dataset
data.dtypes
# Out:
# EmpNumber                       object
# Age                              int64
# Gender                          object
# EducationBackground             object
# MaritalStatus                   object
# EmpDepartment                   object
# EmpJobRole                      object
# BusinessTravelFrequency         object
# DistanceFromHome                 int64
# EmpEducationLevel                int64
# EmpEnvironmentSatisfaction       int64
# EmpHourlyRate                    int64
# EmpJobInvolvement                int64
# EmpJobLevel                      int64
# EmpJobSatisfaction               int64
# NumCompaniesWorked               int64
# OverTime                        object
# EmpLastSalaryHikePercent         int64
# EmpRelationshipSatisfaction      int64
# TotalWorkExperienceInYears       int64
# TrainingTimesLastYear            int64
# EmpWorkLifeBalance               int64
# ExperienceYearsAtThisCompany     int64
# ExperienceYearsInCurrentRole     int64
# ...

# %%
#statistical information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
#check for null values in dataset
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
#cehck for duplicated values in dataset
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# * As it stands, there is no duplicated value in the dataset

# %% [markdown]
# # Distribution of Categorical features in dataset

# %%
# To see the Distribution of Categorical features in data set
data.describe(include=['object'])
# Out:
#        EmpNumber Gender EducationBackground MaritalStatus EmpDepartment  \
# count       1200   1200                1200          1200          1200
# unique      1200      2                   6             3             6
# top      E100998   Male       Life Sciences       Married         Sales
# freq           1    725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %% [markdown]
# # Distribution of Numerical features in data set

# %%
# To know the max , min, std of values 
data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %% [markdown]
# # **Feature Encoding**
# *Coverting Categorical Columns into Numerical Columns*

# %%
#Gender
data['Gender'].value_counts()
# Out:
# Gender
# Male      725
# Female    475
# Name: count, dtype: int64

# %%
# Create a new numerical columns
data['Gender_Num'] = data['Gender'].map({'Male': 1, 'Female': 0})

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  TotalWorkExperienceInYears  TrainingTimesLastYear  \
# ...

# %%
data = data.drop(columns=['Gender'])

# %%
data.head()
# Out:
#   EmpNumber  Age EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32           Marketing        Single            Sales
# 1  E1001006   47           Marketing        Single            Sales
# 2  E1001007   40       Life Sciences       Married            Sales
# 3  E1001009   41     Human Resources      Divorced  Human Resources
# 4  E1001010   60           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# 0                  3                           4  ...
# 1                  4                           4  ...
# ...

# %% [markdown]
# Education Background

# %%
data['EducationBackground'].value_counts()
# Out:
# EducationBackground
# Life Sciences       492
# Medical             384
# Marketing           137
# Technical Degree    100
# Other                66
# Human Resources      21
# Name: count, dtype: int64

# %%
data['Education'] = data['EducationBackground'].map({'Life Sciences': 1,'Medical': 2, 'Marketing': 3,'Technical Degree': 4,'Other': 5,'Human Resources': 6})

# %%
data.head()
# Out:
#   EmpNumber  Age EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32           Marketing        Single            Sales
# 1  E1001006   47           Marketing        Single            Sales
# 2  E1001007   40       Life Sciences       Married            Sales
# 3  E1001009   41     Human Resources      Divorced  Human Resources
# 4  E1001010   60           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  ...  TrainingTimesLastYear  \
# 0                  3                           4  ...                      2
# ...

# %%
data = data.drop(columns=['EducationBackground'])

# %%
data.head()
# Out:
#   EmpNumber  Age MaritalStatus    EmpDepartment       EmpJobRole  \
# 0  E1001000   32        Single            Sales  Sales Executive
# 1  E1001006   47        Single            Sales  Sales Executive
# 2  E1001007   40       Married            Sales  Sales Executive
# 3  E1001009   41      Divorced  Human Resources          Manager
# 4  E1001010   60        Single            Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
# 2       Travel_Frequently                 5                  4
# 3           Travel_Rarely                10                  4
# 4           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  ...  TrainingTimesLastYear  \
# 0                           4             55  ...                      2
# ...

# %% [markdown]
# Marital Status

# %%
data['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     548
# Single      384
# Divorced    268
# Name: count, dtype: int64

# %%
data['MaritalStatus_num'] = data['MaritalStatus'].map({'Married': 2,'Single': 1, 'Divorced': 0})

# %%
data=data.drop(columns=['MaritalStatus'])

# %%
data.head()
# Out:
#   EmpNumber  Age    EmpDepartment       EmpJobRole BusinessTravelFrequency  \
# 0  E1001000   32            Sales  Sales Executive           Travel_Rarely
# 1  E1001006   47            Sales  Sales Executive           Travel_Rarely
# 2  E1001007   40            Sales  Sales Executive       Travel_Frequently
# 3  E1001009   41  Human Resources          Manager           Travel_Rarely
# 4  E1001010   60            Sales  Sales Executive           Travel_Rarely
#
#    DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0                10                  3                           4
# 1                14                  4                           4
# 2                 5                  4                           4
# 3                10                  4                           2
# 4                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  ...  EmpWorkLifeBalance  \
# ...

# %%
data= data.drop(columns=['EmpNumber'])

# %% [markdown]
# EmpDepartment

# %%
data['EmpDepartment'].value_counts()
# Out:
# EmpDepartment
# Sales                     373
# Development               361
# Research & Development    343
# Human Resources            54
# Finance                    49
# Data Science               20
# Name: count, dtype: int64

# %%
data['Department'] = data['EmpDepartment'].map({'Sales': 0,'Development': 1,'Research & Development': 2,'Human Resources': 3,'Finance': 4,'Data Science': 5})

# %%
data = data.drop(columns=['EmpDepartment'])

# %%
data.head()
# Out:
#    Age       EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0   32  Sales Executive           Travel_Rarely                10
# 1   47  Sales Executive           Travel_Rarely                14
# 2   40  Sales Executive       Travel_Frequently                 5
# 3   41          Manager           Travel_Rarely                10
# 4   60  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0                  3                           4             55
# 1                  4                           4             42
# 2                  4                           4             48
# 3                  4                           2             73
# 4                  4                           1             84
#
#    EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  ...  \
# 0                  3            2                   4  ...
# 1                  3            2                   1  ...
# ...

# %% [markdown]
# EmpJobRole

# %%
data['EmpJobRole'].value_counts()
# Out:
# EmpJobRole
# Sales Executive              270
# Developer                    236
# Manager R&D                   94
# Research Scientist            77
# Sales Representative          69
# Laboratory Technician         64
# Senior Developer              52
# Manager                       51
# Finance Manager               49
# Human Resources               45
# Technical Lead                38
# Manufacturing Director        33
# Healthcare Representative     33
# Data Scientist                20
# Research Director             19
# Business Analyst              16
# Senior Manager R&D            15
# Delivery Manager              12
# Technical Architect            7
# Name: count, dtype: int64

# %%
job_role_mapping = {
    'Sales Executive': 0,
    'Developer': 1,
    'Manager R&D': 2,
    'Research Scientist': 2,  
    'Sales Representative': 0,  
    'Laboratory Technician': 2,  
    'Senior Developer': 1,  
    'Manager': 2,  
    'Finance Manager': 4,
    'Human Resources': 3,
    'Technical Lead': 1,  
    'Manufacturing Director': 2,  
    'Healthcare Representative': 0,  
    'Data Scientist': 5,
    'Research Director': 2,  
    'Business Analyst': 1,  
    'Senior Manager R&D': 2,  
    'Delivery Manager': 2, 
    'Technical Architect': 1  
}

data['Department'] = data['EmpJobRole'].map(job_role_mapping)

# %%
data = data.drop(columns=['EmpJobRole'])

# %%
data.head()
# Out:
#    Age BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0   32           Travel_Rarely                10                  3
# 1   47           Travel_Rarely                14                  4
# 2   40       Travel_Frequently                 5                  4
# 3   41           Travel_Rarely                10                  4
# 4   60           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  \
# 0                           4             55                  3            2
# 1                           4             42                  3            2
# 2                           4             48                  2            3
# 3                           2             73                  2            5
# 4                           1             84                  3            2
#
#    EmpJobSatisfaction  NumCompaniesWorked  ... ExperienceYearsAtThisCompany  \
# ...

# %% [markdown]
# BusinessTravelFrequency

# %%
data['BusinessTravelFrequency'].value_counts()
# Out:
# BusinessTravelFrequency
# Travel_Rarely        846
# Travel_Frequently    222
# Non-Travel           132
# Name: count, dtype: int64

# %%
travel_frequency_mapping = {
    'Travel_Rarely': 0,
    'Travel_Frequently': 1,
    'Non-Travel': 2
}

data['BusinessTravel'] = data['BusinessTravelFrequency'].map(travel_frequency_mapping)

# %%
data = data.drop(columns=['BusinessTravelFrequency'])

# %%
data.head()
# Out:
#    Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0   32                10                  3                           4
# 1   47                14                  4                           4
# 2   40                 5                  4                           4
# 3   41                10                  4                           2
# 4   60                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  \
# 0             55                  3            2                   4
# 1             42                  3            2                   1
# 2             48                  2            3                   1
# 3             73                  2            5                   4
# 4             84                  3            2                   1
#
#    NumCompaniesWorked OverTime  ...  ExperienceYearsInCurrentRole  \
# ...

# %% [markdown]
# Overtime

# %%
data['OverTime'].value_counts()
# Out:
# OverTime
# No     847
# Yes    353
# Name: count, dtype: int64

# %%
data['Overtime'] = data['OverTime'].map({'No':0, 'Yes':1})

# %%
data = data.drop(columns=['OverTime'])

# %%
data.head()
# Out:
#    Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0   32                10                  3                           4
# 1   47                14                  4                           4
# 2   40                 5                  4                           4
# 3   41                10                  4                           2
# 4   60                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  \
# 0             55                  3            2                   4
# 1             42                  3            2                   1
# 2             48                  2            3                   1
# 3             73                  2            5                   4
# 4             84                  3            2                   1
#
#    NumCompaniesWorked  EmpLastSalaryHikePercent  ...  YearsSinceLastPromotion  \
# ...

# %% [markdown]
# Attrition

# %%
data['Attrition'].value_counts()
# Out:
# Attrition
# No     1022
# Yes     178
# Name: count, dtype: int64

# %%
data['Attrition_num'] = data['Attrition'].map({'No':0, 'Yes':1})

# %%
data = data.drop(columns=['Attrition'])

# %%
data.head()
# Out:
#    Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0   32                10                  3                           4
# 1   47                14                  4                           4
# 2   40                 5                  4                           4
# 3   41                10                  4                           2
# 4   60                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  \
# 0             55                  3            2                   4
# 1             42                  3            2                   1
# 2             48                  2            3                   1
# 3             73                  2            5                   4
# 4             84                  3            2                   1
#
#    NumCompaniesWorked  EmpLastSalaryHikePercent  ...  YearsSinceLastPromotion  \
# ...

# %% [markdown]
# # Feature Selection

# %%
data.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# NumCompaniesWorked            0.284408         -0.021411           0.128674
# EmpLastSalaryHikePercent     -0.006105          0.044974           0.002358
# EmpRelationshipSatisfaction   0.049749         -0.009509          -0.016690
# ...

# %%
# HeatMapAnalysis
plt.figure(figsize=(30,25))
sns.heatmap(data.drop("PerformanceRating",axis=1).corr(),cmap=plt.cm.Spectral_r,annot=True)
plt.title("HeatMapAnalysis")
plt.xlabel("columns_x",fontsize=10)
plt.ylabel("columns_y",fontsize=10)
plt.show()

# %% [markdown]
# This heatmap presents the pairwise correlation between all numerical features in the dataset, excluding the target variable PerformanceRating. Each cell in the matrix quantifies the strength and direction of the linear relationship between two features, ranging from -1 (perfect negative correlation) to +1 (perfect positive correlation).
# - Color Gradient: The Spectral_r colormap highlights strong correlations with vibrant contrast, making it easy to spot highly related features.
# - Annotations: Each cell is labeled with its correlation coefficient for precise interpretation.
# - Axes: columns_x and columns_y represent the feature names being compared.
# This analysis is critical for:
# - Identifying multicollinearity that may affect model performance
# - Selecting or engineering features for predictive modeling
# - Understanding how operational metrics (e.g., years of experience, salary hike) interact

# %%
def correlation(dataset,threshold):
  col_corr=set()
  matrix=dataset.corr()
  for i in range(len(matrix.columns)):
    for j in range(i):
      if(matrix.iloc[i,j]>threshold):
        col_name=matrix.columns[i]
        col_corr.add(col_name)
      return col_corr

# %%
features=correlation(data,0.7)
len(set(features))
# Out:
# 0

# %%
data.head()
# Out:
#    Age  DistanceFromHome  EmpEducationLevel  EmpEnvironmentSatisfaction  \
# 0   32                10                  3                           4
# 1   47                14                  4                           4
# 2   40                 5                  4                           4
# 3   41                10                  4                           2
# 4   60                16                  4                           1
#
#    EmpHourlyRate  EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  \
# 0             55                  3            2                   4
# 1             42                  3            2                   1
# 2             48                  2            3                   1
# 3             73                  2            5                   4
# 4             84                  3            2                   1
#
#    NumCompaniesWorked  EmpLastSalaryHikePercent  ...  YearsSinceLastPromotion  \
# ...

# %%
data.to_csv('preprocessed_data.csv', index=False)
